# %% [markdown]
# ## Scratch - Pandas Dataframe demo
#
# In this notebook, we demonstrate how to work with data using Pandas, and visualize it using Matplotlib and Seaborn. This notebook might lead to unwished reactions for users with a cat allergy.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Say hello to Annika with some cat fun! 😸
print("Hey Annika! 🎉 Time for some cat-tastic data visualization! 🐾 Let's see which cat breed reigns supreme!")

# Cat data: Name of breeds and their "popularity"
data = {
    'Cat Breed': ['Persian', 'Maine Coon', 'Bengal', 'Siamese', 'Ragdoll'],
    'Popularity': [85, 95, 90, 75, 88]
}

df = pd.DataFrame(data)

# Plotting with Seaborn (because cats deserve the best!)
plt.figure(figsize=(8, 6))
sns.barplot(x='Cat Breed', y='Popularity', data=df, palette='coolwarm')
plt.title('Cat Breeds Popularity (Based on Feline Fandom 😻)')
plt.xlabel('Cat Breed')
plt.ylabel('Popularity')
plt.show()

# Ending with more cat love 🐱
print("And that's how cats rule the world of data visualization! Go ahead, Annika, and become a cat data expert! 🐾💻")
# Out:
# Hey Annika! 🎉 Time for some cat-tastic data visualization! 🐾 Let's see which cat breed reigns supreme!
# /var/folders/kq/d9z75f9s3d5dd23h07ssfc7r0000gp/T/ipykernel_14861/37879250.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Cat Breed', y='Popularity', data=df, palette='coolwarm')
# And that's how cats rule the world of data visualization! Go ahead, Annika, and become a cat data expert! 🐾💻
